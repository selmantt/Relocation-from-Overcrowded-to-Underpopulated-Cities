# %% [markdown]
# # YZV202 - Term Project
# ## Strategic Relocation from Overcrowded to Underpopulated Cities in Türkiye
# **Nurullah Eren Acar - Ömer Faruk Satık - Selman Turan Toker**

# %%
import pandas as pd
import folium
import numpy as np
import random
from geneticalgorithm import geneticalgorithm as ga
np.random.seed(2*5)

# %% [markdown]
# ### Data Loading and Understanding

# %%
df_population = pd.read_csv("population.csv")
df_population
# Out:
#              Şehir     Nüfus
# 0            Adana   2270298
# 1         Adıyaman    415273
# 2   Afyonkarahisar    458364
# 3          Aksaray    316264
# 4           Amasya    248218
# ..             ...       ...
# 76           Çorum    388640
# 77        İstanbul  15655924
# 78           İzmir   4479525
# 79       Şanlıurfa   2213964
# 80          Şırnak    383388
#
# [81 rows x 2 columns]

# %%
df_location = pd.read_csv("location.csv")
df_location
# Out:
#     plaka           il_adi        lat        lon  northeast_lat  \
# 0       1            Adana  37.000000  35.321333      37.072004
# 1       2         Adıyaman  37.764167  38.276167      37.825667
# 2       3  Afyonkarahi̇sar  38.763760  30.540340      38.802105
# 3      68          Aksaray  38.368690  34.036980      38.446724
# 4       5           Amasya  40.650000  35.833333      40.672834
# ..    ...              ...        ...        ...            ...
# 76     19            Çorum  40.550556  34.955556      40.609317
# 77     34         İstanbul  41.005270  28.976960      41.320786
# 78     35           İzmi̇r  38.418850  27.128720      38.506773
# 79     63        Şanlıurfa  37.150000  38.800000      37.189639
# 80     73           Şırnak  37.516389  42.461111      37.533572
#
#     northeast_lon  southwest_lat  southwest_lon
# 0       35.461995      36.935523      35.174706
# 1       38.335465      37.717086      38.188188
# 2       30.611167      38.714289      30.442320
# 3       34.088698      38.297012      33.932515
# 4       35.856321      40.636911      35.789091
# ..            ...            ...            ...
# 76      35.006438      40.495214      34.887634
# 77      29.456456      40.802750      27.971307
# 78      27.304415      38.343157      27.017192
# 79      38.840876      37.098274      38.767868
# 80      42.471127      37.500093      42.444631
#
# [81 rows x 8 columns]

# %%
df_merged = pd.concat([df_population, df_location[["lat", "lon"]]], axis=1)
df_merged
# Out:
#              Şehir     Nüfus        lat        lon
# 0            Adana   2270298  37.000000  35.321333
# 1         Adıyaman    415273  37.764167  38.276167
# 2   Afyonkarahisar    458364  38.763760  30.540340
# 3          Aksaray    316264  38.368690  34.036980
# 4           Amasya    248218  40.650000  35.833333
# ..             ...       ...        ...        ...
# 76           Çorum    388640  40.550556  34.955556
# 77        İstanbul  15655924  41.005270  28.976960
# 78           İzmir   4479525  38.418850  27.128720
# 79       Şanlıurfa   2213964  37.150000  38.800000
# 80          Şırnak    383388  37.516389  42.461111
#
# [81 rows x 4 columns]

# %% [markdown]
# ### Visualize Population Data on Map

# %%
map = folium.Map(location=[39.9334, 35.1597], zoom_start=6)

for i in range(len(df_merged)):
    folium.CircleMarker([df_merged.loc[i, 'lat'], df_merged.loc[i, 'lon']], radius=df_merged.loc[i, 'Nüfus']/150000,
                        popup=f"{df_merged.loc[i,'Şehir']}: {df_merged.loc[i,'Nüfus']}", fill=True).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7cd864bc747940c022af5740e4acd91c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7cd864bc747940c022af5740e4acd91c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7cd864bc747940c022af5740e4acd91c = L.map(
#                 &quot;map_7cd864bc747940c022af5740e4acd91c&quot;,
#                 {
#                     center: [39.9334, 35.1597],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_469b8b7365adb60b1b7405bba739f13f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7cd864bc747940c022af5740e4acd91c);
#
#
#             var circle_marker_66649184cc16ece33c33c6a7a0b4e17f = L.circleMarker(
#                 [37.0, 35.3213333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 15.13532, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7cd864bc747940c022af5740e4acd91c);
#
#
#         var popup_88a57780f302917fab362141572a43bb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4388ec93b917266c9052989153b1560b = $(`&lt;div id=&quot;html_4388ec93b917266c9052989153b1560b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adana: 2270298&lt;/div&gt;`)[0];
#                 popup_88a57780f302917fab362141572a43bb.setContent(html_4388ec93b917266c9052989153b1560b);
#
#
#
#         circle_marker_66649184cc16ece33c33c6a7a0b4e17f.bindPopup(popup_88a57780f302917fab362141572a43bb)
#         ;
#
#
#
#
#             var circle_marker_aac0727aa96459ac66bbe50315347283 = L.circleMarker(
#                 [37.7641667, 38.2761667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2.7684866666666665, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7cd864bc747940c022af5740e4acd91c);
#
#
#         var popup_12960434ba45d47bfa9d24e77f37583e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f97d1a11f9c6b1f33683b59b065129be = $(`&lt;div id=&quot;html_f97d1a11f9c6b1f33683b59b065129be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adıyaman: 415273&lt;/div&gt;`)[0];
#                 popup_12960434ba45d47bfa9d24e77f37583e.setContent(html_f97d1a11f9c6b1f33683b59b065129be);
#
#
#
#         circle_marker_aac0727aa96459ac66bbe50315347283.bindPopup(popup_12960434ba45d47bfa9d24e77f37583e)
#         ;
#
#
#
#
#             var circle_marker_3bd2c65c7be3edd44f9da14d8e48b6cd = L.circleMarker(
#                 [38.76376, 30.54034],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3.05576, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7cd864bc747940c022af5740e4acd91c);
#
#
#         var popup_f547a81920af61b09ae4e17bf661b164 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a7e66a53e94d74bfa5f802df189fc7b5 = $(`&lt;div id=&quot;html_a7e66a53e94d74bfa5f802df189fc7b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Afyonkarahisar: 458364&lt;/div&gt;`)[0];
#                 popup_f547a81920af61b09ae4e17bf661b164.setContent(html_a7e66a53e94d74bfa5f802df189fc7b5);
#
#
#
#         circle_marker_3bd2c65c7be3edd44f9da14d8e48b6cd.bindPopup(popup_f547a81920af61b09ae4e17bf661b164)
#         ;
#
#
#
#
#             var circle_marker_9af7b4e8d7761b65bdd2c9a50ac208ab = L.circleMarker(
#                 [38.36869, 34.03698],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &q

# %% [markdown]
# Looking at the map, it is clear that many cities, especially Istanbul, are more crowded than they should be.

# %%
df_rivalry = pd.read_excel("rekabet.xlsx")
df_rivalry
# Out:
#                 İl  Demografi Endeksi  Altyapı Endeksi  Ulaşım Endeksi  \
# 0            Adana          54.043240         71.71727       50.987720
# 1         Adıyaman          36.345699         60.05851       35.869290
# 2   Afyonkarahisar          39.648615         66.20314       23.059490
# 3          Aksaray          37.962947         62.67711        9.516613
# 4           Amasya          44.165865         63.67748       36.160810
# ..             ...                ...              ...             ...
# 76           Çorum          37.318436         68.15917        9.152143
# 77        İstanbul          80.285020         86.79449       91.064610
# 78           İzmir          66.298300         73.70824       63.349060
# 79       Şanlıurfa          24.490249         50.24007       39.360920
# 80          Şırnak          27.746976         44.88142       13.986530
#
#     Sağlık Endeksi  Sosyal Yaşam Endeksi  Eğitim Endeksi
# 0         42.31910             22.025460        39.04998
# 1         30.85775             13.299610        45.49229
# 2         34.23103             21.439440        50.91570
# 3         31.18841             16.508088        49.26588
# 4         31.97616             22.357690        62.22447
# ..             ...                   ...             ...
# 76        32.32822             21.419630        56.78364
# 77        65.82729             85.161580        38.35243
# 78        43.92970             41.629820        49.42108
# 79        33.12352             10.883530        25.83354
# 80        27.95350              8.846442        27.59788
#
# [81 rows x 7 columns]

# %%
pop_densities = pd.read_csv("population_density.csv")
area = df_population["Nüfus"] / pop_densities["Nüfus Yoğunluğu"]
area.name = "Yüz Ölçümü"
area
# Out:
# 0     13928.208589
# 1      4828.755814
# 2      8814.692308
# 3      5452.827586
# 4      4136.966667
#           ...
# 76     9479.024390
# 77     5196.124793
# 78    12009.450402
# 79    18762.406780
# 80     4792.350000
# Name: Yüz Ölçümü, Length: 81, dtype: float64

# %% [markdown]
# ### Collect the features to be used in calculating the optimal population of each city in a single data frame

# %%
df = pd.concat([df_population, area,df_rivalry.iloc[:,1:]], axis=1)
df
# Out:
#              Şehir     Nüfus    Yüz Ölçümü  Demografi Endeksi  \
# 0            Adana   2270298  13928.208589          54.043240
# 1         Adıyaman    415273   4828.755814          36.345699
# 2   Afyonkarahisar    458364   8814.692308          39.648615
# 3          Aksaray    316264   5452.827586          37.962947
# 4           Amasya    248218   4136.966667          44.165865
# ..             ...       ...           ...                ...
# 76           Çorum    388640   9479.024390          37.318436
# 77        İstanbul  15655924   5196.124793          80.285020
# 78           İzmir   4479525  12009.450402          66.298300
# 79       Şanlıurfa   2213964  18762.406780          24.490249
# 80          Şırnak    383388   4792.350000          27.746976
#
#     Altyapı Endeksi  Ulaşım Endeksi  Sağlık Endeksi  Sosyal Yaşam Endeksi  \
# 0          71.71727       50.987720        42.31910             22.025460
# 1          60.05851       35.869290        30.85775             13.299610
# 2          66.20314       23.059490        34.23103             21.439440
# 3          62.67711        9.516613        31.18841             16.508088
# 4          63.67748       36.160810        31.97616             22.357690
# ..              ...             ...             ...                   ...
# 76         68.15917        9.152143        32.32822             21.419630
# 77         86.79449       91.064610        65.82729             85.161580
# 78         73.70824       63.349060        43.92970             41.629820
# 79         50.24007       39.360920        33.12352             10.883530
# 80         44.88142       13.986530        27.95350              8.846442
#
#     Eğitim Endeksi
# 0         39.04998
# 1         45.49229
# 2         50.91570
# 3         49.26588
# 4         62.22447
# ..             ...
# 76        56.78364
# 77        38.35243
# 78        49.42108
# 79        25.83354
# 80        27.59788
#
# [81 rows x 9 columns]

# %% [markdown]
# ######################################################################################################################

# %% [markdown]
# ### Calculate coefficients of objective functions variables

# %%
transp_coefficient = 0
dem_coefficient = 0
health_coefficient = 0
infr_coefficient = 0
edu_coefficient = 0
social_coefficient = 0

df_co = pd.read_csv('coefficient_index.csv', encoding='utf-8', decimal=',')
df_co['Coefficient'] = pd.to_numeric(df_co['Coefficient'], errors='coerce')
df_co = df_co.dropna(subset=['Coefficient'])

df_co['Labels'] = df_co['Label'].str.split(',')
df_co = df_co.explode('Labels')

total_values = df_co.groupby('Labels')['Coefficient'].sum()


label_count = df_co['Labels'].value_counts()
means = total_values / label_count


c_transp = means.get('ULS', 0)
c_dem = means.get('DEM', 0)
c_health = means.get('SAG', 0)
c_infr = means.get('ALT', 0)
c_edu = means.get('EGT', 0)
c_soc = means.get('SY', 0)

# %%
print(c_dem, c_infr,  c_transp, c_health, c_soc, c_edu)
# Out:
# 0.6562 0.6011428571428572 0.603 0.6072 0.5834230769230769 0.6806666666666668

# %% [markdown]
# ## GENETIC ALGORITHM

# %% [markdown]
# **The fitness function calculates the total score of each province. Normally, our goal is to maximize this function, but since the genetic algorithm works to minimize it, we turn the problem into a minimization problem by taking the negative of the function.**

# %%
def function1(X):
    dist_from_ratio = 0
    all_area = df.iloc[:,2]
    all_dem = df.iloc[:,3]
    all_infr = df.iloc[:,4]
    all_transp = df.iloc[:,5]
    all_health = df.iloc[:,6]
    all_social = df.iloc[:,7]
    all_edu = df.iloc[:,8]
    all_pop_density = df["Nüfus"].sum() / df["Yüz Ölçümü"].sum()
    
    ratio = (c_dem*all_dem + c_infr*all_infr + c_transp*all_transp + c_health*all_health + c_soc*all_social + c_edu*all_edu + 10*all_area).sum() / df["Nüfus"].sum()

    for i in range(len(df)):
        area = all_area[i]
        dem = all_dem[i]
        infr = all_infr[i]
        transp = all_transp[i]
        health = all_health[i]
        social = all_social[i]
        edu = all_edu[i]
        pop_density = X[i] / area
        
        city_ratio = (c_dem*dem + c_infr*infr + c_transp*transp + c_health*health + c_soc*social + c_edu*edu + 10*area) / X[i]
        dist_from_ratio += abs(ratio - city_ratio)

    return dist_from_ratio

# %%
from geneticalgorithm import geneticalgorithm as ga
varbound = np.array([[initial_population[i] * 0.3, initial_population[i] * 1.7] for i in range(len(initial_population))])

algorithm_param = {
    'max_num_iteration': 1000,
    'population_size': 500,
    'mutation_probability': 0.01,
    'elit_ratio': 0.1,
    'crossover_probability': 0.5,
    'parents_portion': 0.3,
    'crossover_type': 'uniform',
    'max_iteration_without_improv': 50
}

model = ga(function=function1,
           dimension=len(df),
           variable_type='int',
           variable_boundaries=varbound,
           algorithm_parameters=algorithm_param,
           function_timeout=1)

model.run()

# Output the best population distribution found
best_population = model.output_dict['variable']
print("Best population distribution:", best_population)
# Out:
#  The best solution found:
#  [1092971.  378008.  688850.  427351.  325704. 1917345. 1621654.   67941.
#   177644.  613221.  526132. 1118657.   77739.  298362.   84295.  279465.
#   321215.  355799.  400418.  331350.  968666.  913083. 1173136.  138463.
#   360937.  504065.  307553. 1274391. 1084228.  656275.  334875.  125284.
#   314314.  464559.  488997.  167207. 1117518.  242249.  341492.  250705.
#   408201. 1329600.  303927.  359838.  335112.   88581.  644064. 3023654.
#   685297.  921664. 1023837.  687401. 1211689. 1003913.  302216.  277172.
#   345230.  465606.  188784.  195338.  377828.  708657.  296202.  238172.
#   818049.  494499.  505369.  364180.   98278.  317427. 1517132.   66264.
#   469118.  164116.  485024.  230516.  659817. 4723690. 1343893. 1468615.
#   375098.]
#
#  Objective function:
#  31.631124501810444
# Best population distribution: [1092971.  378008.  688850.  427351.  325704. 1917345. 1621654.   67941.
#   177644.  613221.  526132. 1118657.   77739.  298362.   84295.  279465.
#   321215.  355799.  400418.  331350.  968666.  913083. 1173136.  138463.
#   360937.  504065.  307553. 1274391. 1084228.  656275.  334875.  125284.
#   314314.  464559.  488997.  167207. 1117518.  242249.  341492.  250705.
#   408201. 1329600.  303927.  359838.  335112.   88581.  644064. 3023654.
#   685297.  921664. 1023837.  687401. 1211689. 1003913.  302216.  277172.
#   345230.  465606.  188784.  195338.  377828.  708657.  296202.  238172.
#   818049.  494499.  505369.  364180.   98278.  317427. 1517132.   66264.
#   469118.  164116.  485024.  230516.  659817. 4723690. 1343893. 1468615.
#   375098.]

# %%
best_population.sum()
# Out:
# 51855186.0

# %% [markdown]
# **The total population is not matching because the genetic algorithm does not accept any constraint function. But keeping the calculated ratio, we can scale the total population to equal the actual population.**

# %%
scale_factor = df["Nüfus"].sum() / best_population.sum()
best_population = best_population*scale_factor
best_population
# Out:
# array([1673528.34442696,  578795.87145509, 1054748.93666759,
#         654348.57056519,  498709.36730548, 2935788.05251494,
#        2483033.7985668 ,  104029.4657852 ,  272003.80359349,
#         938947.80821984,  805599.4302777 , 1712858.0696026 ,
#         119031.90475082,  456844.01864269,  129070.27889438,
#         427909.43106018,  491835.92900004,  544790.0368983 ,
#         613109.47190617,  507354.37346999, 1483195.80966255,
#        1398088.58726755, 1796274.8763395 ,  212010.89064064,
#         552657.20687231,  771811.02237257,  470917.03523108,
#        1951313.8595467 , 1660141.29361287, 1004870.95653846,
#         512751.7604218 ,  191831.55372209,  481269.29996332,
#         711320.47799863,  748739.2985173 ,  256022.94469533,
#        1711114.06286839,  370925.27423791,  522883.53615517,
#         383872.87822784,  625026.59606104, 2035848.42301405,
#         465364.99974533,  550974.44708223,  513114.6485658 ,
#         135632.88895834,  986173.79566796, 4629739.19046338,
#        1049308.67685489, 1411227.58795789, 1567672.18853297,
#        1052530.26611633, 1855306.21226945, 1537165.08565982,
#         462745.16171   ,  424398.4499877 ,  528607.06308449,
#         712923.61676134,  289061.07753481,  299096.38933117,
#         578520.26020649, 1085076.89222914,  453536.68365945,
#         364682.67945706, 1252575.03504679,  757163.81568293,
#         773807.67275134,  557622.80286797,  150480.67939002,
#         486035.84339055, 2322992.47119746,  101461.68765238,
#         718301.0984563 ,  251290.08708737,  742655.94579119,
#         352960.01434981, 1010294.37344153, 7232789.43840795,
#        2057733.48732673, 2248704.52148373,  574340.15626935])

# %%
np.round(best_population).sum()
# Out:
# 79399290.0

# %%
optimum_populations = np.round(best_population)
min_ind = np.where(optimum_populations==optimum_populations.min())
optimum_populations[min_ind] += df["Nüfus"].sum() - np.sum(optimum_populations)

# %%
optimum_populations.sum()
# Out:
# 79399292.0

# %% [markdown]
# ### Visualize optimum populations

# %%
df_optimum_populations = pd.Series(optimum_populations)
df_optimum_populations.name = "Nüfus"
df_merged_opt = pd.concat([df["Şehir"], df_optimum_populations, df_location[["lat", "lon"]]], axis=1)

# %%
map = folium.Map(location=[39.9334, 35.1597], zoom_start=6)

for i in range(len(df_merged_opt)):
    folium.CircleMarker([df_merged_opt.loc[i, 'lat'], df_merged_opt.loc[i, 'lon']], radius=df_merged_opt.loc[i, 'Nüfus']/150000,
                        popup=f"{df_merged_opt.loc[i,'Şehir']}: {df_merged_opt.loc[i,'Nüfus']}", fill=True).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3a1961da8d5d2181de824c9bc447893d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3a1961da8d5d2181de824c9bc447893d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3a1961da8d5d2181de824c9bc447893d = L.map(
#                 &quot;map_3a1961da8d5d2181de824c9bc447893d&quot;,
#                 {
#                     center: [39.9334, 35.1597],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_754d3c6c1b7af377ac20249d60ce3657 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3a1961da8d5d2181de824c9bc447893d);
#
#
#             var circle_marker_19b4b49944891efde63f86028565301c = L.circleMarker(
#                 [37.0, 35.3213333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 11.156853333333334, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3a1961da8d5d2181de824c9bc447893d);
#
#
#         var popup_fd0525252038745b4bc81f5198a8a884 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c08d737b44b3b26e24f7d464d3434337 = $(`&lt;div id=&quot;html_c08d737b44b3b26e24f7d464d3434337&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adana: 1673528.0&lt;/div&gt;`)[0];
#                 popup_fd0525252038745b4bc81f5198a8a884.setContent(html_c08d737b44b3b26e24f7d464d3434337);
#
#
#
#         circle_marker_19b4b49944891efde63f86028565301c.bindPopup(popup_fd0525252038745b4bc81f5198a8a884)
#         ;
#
#
#
#
#             var circle_marker_336157abbe86aa137aca6c6c22cd2875 = L.circleMarker(
#                 [37.7641667, 38.2761667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3.85864, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3a1961da8d5d2181de824c9bc447893d);
#
#
#         var popup_bc88a96c3672eb0cf112dc13326805e7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f0fc5431ce7b68872b8b86f23aff44ed = $(`&lt;div id=&quot;html_f0fc5431ce7b68872b8b86f23aff44ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Adıyaman: 578796.0&lt;/div&gt;`)[0];
#                 popup_bc88a96c3672eb0cf112dc13326805e7.setContent(html_f0fc5431ce7b68872b8b86f23aff44ed);
#
#
#
#         circle_marker_336157abbe86aa137aca6c6c22cd2875.bindPopup(popup_bc88a96c3672eb0cf112dc13326805e7)
#         ;
#
#
#
#
#             var circle_marker_9aeabe043d2257aa89e8b1a957b9d383 = L.circleMarker(
#                 [38.76376, 30.54034],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7.03166, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3a1961da8d5d2181de824c9bc447893d);
#
#
#         var popup_8fcf749b48266629babc83c24d4f0bf1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8243d1382930720512c5e48838de6a41 = $(`&lt;div id=&quot;html_8243d1382930720512c5e48838de6a41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Afyonkarahisar: 1054749.0&lt;/div&gt;`)[0];
#                 popup_8fcf749b48266629babc83c24d4f0bf1.setContent(html_8243d1382930720512c5e48838de6a41);
#
#
#
#         circle_marker_9aeabe043d2257aa89e8b1a957b9d383.bindPopup(popup_8fcf749b48266629babc83c24d4f0bf1)
#         ;
#
#
#
#
#             var circle_marker_348ca7ab8d69b6d456d09748094ffdf7 = L.circleMarker(
#                 [38.36869, 34.03698],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: nu

# %% [markdown]
# ## LINEAR PROGRAMMING

# %%
population_data = pd.read_csv('population.csv')

# Optimum population values to concatenate
optimum_population_values = list(optimum_populations)

# Check if the number of rows matches the number of new values
if len(df) == len(optimum_population_values):
    # Add the new column
    df['Optimum Population'] = optimum_population_values
    
    # Save the updated DataFrame to a new CSV file
    updated_file_path = 'optimum_population.csv'
    df.to_csv(updated_file_path, index=False)
    result = f"Updated dataset saved to {updated_file_path}"
else:
    result = "The length of the DataFrame and the list of optimized values do not match."

# %%
# Load the population data
population_data = pd.read_csv('data/optimum_population.csv')
#print("Population Data Preview:")
#print(population_data.head())

# Calculate the surplus or deficit
population_data.reset_index(drop=True, inplace=True)
population_data['Surplus_Deficit'] = population_data['Nüfus'] - population_data['Optimum Population']
# Reset index after dropping the first row
# Identify source and destination cities
source_cities = population_data[population_data['Surplus_Deficit'] > 0]
destination_cities = population_data[population_data['Surplus_Deficit'] < 0]

source_cities.to_csv('source_cities.csv', index=False)
destination_cities.to_csv('destination_cities.csv', index=False)


# Print identified cities
# print("Source Cities:")
# print(source_cities)
# print("\nDestination Cities:")
# print(destination_cities)

# %%
source_cities = pd.read_csv('source_cities.csv')
destination_cities = pd.read_csv('destination_cities.csv')

# Sum surplus_deficit column in source_cities.csv
source_sum = source_cities['Surplus_Deficit'].sum()
print("Sum of surplus_deficit in source_cities.csv:", source_sum)


# Sum surplus_deficit column in destination_cities.csv
destination_sum = destination_cities['Surplus_Deficit'].sum()
print("Sum of surplus_deficit in destination_cities.csv:", destination_sum)
# Out:
# Sum of surplus_deficit in source_cities.csv: 43875708.0
# Sum of surplus_deficit in destination_cities.csv: -43875708.0

# %%
def turkish_upper(text):
    turkish_map = {
        'i': 'İ', 'ı': 'I',
        'ğ': 'Ğ', 'ç': 'Ç',
        'ş': 'Ş', 'ö': 'Ö',
        'ü': 'Ü'
    }
    return ''.join(turkish_map.get(c, c.upper()) for c in text)
# Load data
source_cities = pd.read_csv('source_cities.csv')
destination_cities = pd.read_csv('destination_cities.csv')
distances = pd.read_csv('ilmesafe.csv')

# Create dictionaries for populations
source_population = {row['Şehir']: int(row['Surplus_Deficit']) for index, row in source_cities.iterrows()}
destination_capacity = {row['Şehir']: int(abs(row['Surplus_Deficit'])) for index, row in destination_cities.iterrows()}

print('Source Population:', source_population)
print('-------------'*20)
print('Destination Capacity:', destination_capacity)


total_source_population = sum(source_population.values())
total_destination_capacity = sum(destination_capacity.values())
print('Total Source Population:', total_source_population)
print('Total Destination Capacity:', total_destination_capacity)

if total_source_population > total_destination_capacity:
    print('exceeds by: ', total_destination_capacity-total_source_population)
    print("Infeasibility Alert: Total source population exceeds total destination capacity.")
else:
    print('Values do fit.')


# # Print the totals
# print('Total Source Population:', total_source_population)
# print('Total Destination Capacity:', total_destination_capacity)


# Create a lookup table from the distances DataFrame, setting 'İL ADI' as the index
distances.set_index('İL ADI', inplace=True)

# Build the distance matrix correctly mapped by city names
num_source_cities = len(source_cities)
num_destination_cities = len(destination_cities)
distance_matrix = np.zeros((num_source_cities, num_destination_cities))
for i, src_city in enumerate(source_cities['Şehir']):
    src_city = turkish_upper(src_city)
    for j, dest_city in enumerate(destination_cities['Şehir']):
        dest_city = turkish_upper(dest_city)
        if dest_city in distances.columns:
            # print('dest_city', dest_city)
            # print('Distance:', distances.at[src_city, dest_city])
            distance_matrix[i][j] = distances.at[src_city, dest_city]
#
# Define the LP problem
prob = lp.LpProblem("Population_Redistribution", lp.LpMinimize)

# Create variables
transfer = [[lp.LpVariable(f"transfer_{i}_{j}", lowBound=0, cat='Continuous')
             for j in range(num_destination_cities)] for i in range(num_source_cities)]


print("Distance Matrix:\n", distance_matrix)
# distance_matrix = np.random.randint(10, 200, size=(num_source_cities, num_destination_cities))

# Objective function: Minimize total transportation cost
prob += lp.lpSum(transfer[i][j] * distance_matrix[i][j]
                 for i in range(num_source_cities)
                 for j in range(num_destination_cities))

# Constraints
# Each source city's total outgoing population must not exceed its total population
for i, src_city in enumerate(source_cities['Şehir']):
    prob += lp.lpSum(transfer[i][j] for j in range(num_destination_cities)) <= source_population[src_city]

# Demand constraints for each destination city
# Each destination city's incoming population should match its optimum capacity

for j, dest_city in enumerate(destination_cities['Şehir']):
    prob += lp.lpSum(transfer[i][j] for i in range(num_source_cities)) == destination_capacity[dest_city]


# # Adding minimum transfer requirements (e.g., at least 5000 people must be sent)
# min_transfer = 5000  # Minimum number of people each city must send to each destination
# for i in range(num_source_cities):
#     for j in range(num_destination_cities):
#         min_transfer = np.random.randint(3000, 10000)
#         prob += transfer[i][j] >= min_transfer


# Solve the problem
prob.solve()
# Function to collect results, create a dataset, and print the results
def print_and_create_dataset():
    results = []  # List to hold the transfer data
    if lp.LpStatus[prob.status] == 'Optimal':
        print("Optimal solution found:\n")
        for i, src_city in enumerate(source_cities['Şehir']):
            for j, dest_city in enumerate(destination_cities['Şehir']):
                amount = transfer[i][j].value()
                if amount > 0:
                    # Record this transfer in the results list
                    results.append({
                        'Source City': src_city,
                        'Destination City': dest_city,
                        'Amount': int(amount)
                    })
                    # Print the transfer details
                    print(f"{src_city} sent {int(amount):,} people to {dest_city}")
        # Convert list of dictionaries into a DataFrame
        results_df = pd.DataFrame(results)
        return results_df
    else:
        print("No optimal solution. Status:", lp.LpStatus[prob.status])
        return pd.DataFrame()  # Return an empty DataFrame if no solution is found

# Call the function and receive the dataset
transfer_dataset = print_and_create_dataset()

# Optionally, display or save the DataFrame
print(transfer_dataset)
transfer_dataset.to_csv('transfer_results.csv',index=False)
# Out:
# Source Population: {'Adana': 1881808, 'Ankara': 4991953, 'Antalya': 2193307, 'Aydın': 941110, 'Balıkesir': 457546, 'Batman': 141482, 'Bursa': 1929014, 'Diyarbakır': 1454505, 'Düzce': 73684, 'Elazığ': 372699, 'Erzurum': 493448, 'Gaziantep': 1909207, 'Hatay': 831030, 'Kayseri': 1095368, 'Kocaeli': 1962024, 'Manisa': 962716, 'Mardin': 342435, 'Mersin': 796137, 'Ordu': 217552, 'Sakarya': 37574, 'Tekirdağ': 129114, 'İstanbul': 15132288, 'İzmir': 3927881, 'Şanlıurfa': 1601817}
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Destination Capacity: {'Adıyaman': 1024409, 'Afyonkarahisar': 1014623, 'Aksaray': 671164, 'Amasya': 159154, 'Ardahan': 2540860, 'Artvin': 1915266, 'Ağrı': 1254072, 'Bartın': 865406, 'Bayburt': 158443, 'Bilecik': 893701, 'Bingöl': 920673, 'Bitlis': 1926726, 'Bolu': 1183211, 'Burdur': 1536600, 'Denizli': 885447, 'Edirne': 152837, 'Erzincan': 203093, 'Eskişehir': 1379590, 'Giresun': 532272, 'Gümüşhane': 1167256, 'Hakkari': 794538, 'Isparta': 131504, 'Iğdır': 159948, 'Kahramanmaraş': 19160, 'Karabük': 1901297, 'Karaman': 1511750, 'Kars': 1112068, 'Kastamonu': 712515, 'Kırıkkale': 556706, 'Kırklareli': 271368, 'Kırşehir': 658879, 'Kilis': 440683, 'Konya': 120680, 'Kütahya': 397981, 'Malatya': 752216, 'Muğla': 282109, 'Muş': 518376, 'Nevşehir': 528075, 'Niğde': 730747, 'Osmaniye': 356705, 'Rize': 128067, 'Samsun': 659988, 'Siirt': 633070, 'Sinop': 1257297, 'Sivas': 189737, 'Tokat': 105597, 'Trabzon': 170295, 'Tunceli': 725449, 'Uşak': 2596043, 'Van': 695146, 'Yalova': 1664516, 'Yozgat': 297183, 'Zonguldak': 117763, 'Çanakkale': 326019, 'Çankırı': 893068, 'Çorum': 360883, 'Şırnak': 713453}
# Total Source Population: 43875699
# Total Destination Capacity: 43875682
# exceeds by:  -17
# Infeasibility Alert: Total source population exceeds total destination capacity.
# Distance Matrix:
#  [[ 339.  578.  268. ...  590.  582.  720.]
#  [ 732.  255.  224. ...  131.  240. 1150.]
#  [ 885.  287.  460. ...  685.  732. 1267.]
#  ...
#  [1182.  450.  683. ...  495.  611. 1600.]
#  [1244.  327.  695. ...  725.  831. 1626.]
#  [ 111.  935.  624. ...  817.  752.  357.]]
# Optimal solution found:
#
# Adana sent 337,896 people to Adıyaman
# Adana sent 19,160 people to Kahramanmaraş
# Adana sent 350,221 people to Malatya
# Adana sent 92,377 people to Muş
# Adana sent 356,705 people to Osmaniye
# Adana sent 725,449 people to Tunceli
# Ankara sent 671,164 people to Aksaray
# Ankara sent 760,624 people to Ağrı
# Ankara sent 91,432 people to Erzincan
# Ankara sent 556,706 people to Kırıkkale
# Ankara sent 658,879 people to Kırşehir
# Ankara sent 528,075 people to Nevşehir
# Ankara sent 68,342 people to Sivas
# Ankara sent 105,597 people to Tokat
# Ankara sent 297,183 people to Yozgat
# Ankara sent 893,068 people to Çankırı
# Ankara sent 360,883 people to Çorum
# Antalya sent 614,619 people to Burdur
# Antalya sent 1,458,008 people to Karaman
# Antalya sent 120,680 people to Konya
# Aydın sent 659,001 people to Denizli
# Aydın sent 282,109 people to Muğla
# Balıkesir sent 260,641 people to Kütahya
# Balıkesir sent 196,905 people to Çanakkale
# Batman sent 141,482 people to Siirt
# Bursa sent 412,084 people to Bilecik
# Bursa sent 1,379,590 people to Eskişehir
# Bursa sent 137,340 people to Kütahya
# Diyarbakır sent 1,454,505 people to Bitlis
# Düzce sent 73,684 people to Gümüşhane
# Elazığ sent 372,699 people to Bingöl
# Erzurum sent 493,448 people to Ağrı
# Gaziantep sent 686,513 people to Adıyaman
# Gaziantep sent 35,960 people to Bitlis
# Gaziantep sent 491,588 people to Siirt
# Gaziantep sent 695,146 people to Van
# Hatay sent 440,683 people to Kilis
# Hatay sent 390,347 people to Malatya
# Kayseri sent 547,974 people to Bingöl
# Kayseri sent 425,999 people to Muş
# Kayseri sent 121,395 people to Sivas
# Kocaeli sent 159,154 people to Amasya
# Kocaeli sent 138,354 people to Bayburt
# Kocaeli sent 1,664,516 people to Yalova
# Manisa sent 604,766 people to Burdur
# Manisa sent 226,446 people to Denizli
# Manisa sent 131,504 people to Isparta
# Mardin sent 342,435 people to Hakkari
# Mersin sent 53,742 people to Karaman
# Mersin sent 11,648 people to Malatya
# Mersin sent 730,747 people to Niğde
# Ordu sent 47,257 people to Artvin
# Ordu sent 170,295 people to Trabzon
# Sakarya sent 20,089 people to Bayburt
# Sakarya sent 17,485 people to Erzincan
# Tekirdağ sent 129,114 people to Çanakkale
# İstanbul sent 2,540,860 people to Ardahan
# İstanbul sent 1,868,009 people to Artvin
# İstanbul sent 865,406 people to Bartın
# İstanbul sent 481,617 people to Bilecik
# İstanbul sent 1,183,211 people to Bolu
# İstanbul sent 152,837 people to Edirne
# İstanbul sent 94,176 people to Erzincan
# İstanbul sent 532,272 people to Giresun
# İstanbul sent 1,093,572 people to Gümüşhane
# İstanbul sent 159,948 people to Iğdır
# İstanbul sent 1,901,297 people to Karabük
# İstanbul sent 1,112,068 people to Kars
# İstanbul sent 712,515 people to Kastamonu
# İstanbul sent 271,368 people to Kırklareli
# İstanbul sent 128,067 people to Rize
# İstanbul sent 659,988 people to Samsun
# İstanbul sent 1,257,297 people to Sinop
# İstanbul sent 117,763 people to Zonguldak
# İzmir sent 1,014,623 people to Afyonkarahisar
# İzmir sent 317,215 people to Burdur
# İzmir sent 2,596,043 people to Uşak
# Şanlıurfa sent 436,261 people to Bitlis
# Şanlıurfa sent 452,103 people to Hakkari
# Şanlıurfa sent 713,453 people to Şırnak
#    Source City Destination City   Amount
# 0        Adana         Adıyaman   337896
# 1        Adana    Kahramanmaraş    19160
# 2        Adana          Malatya   350221
# 3        Adana              Muş    92377
# 4        Adana         Osmaniye   356705
# ..         ...              ...      ...
# 75       İzmir           Burdur   317215
# 76       İzmir             Uşak  2596043
# 77   Şanlıurfa           Bitlis   436261
# 78   Şanlıurfa          Hakkari   452103
# 79   Şanlıurfa           Şırnak   713453
#
# [80 rows x 3 columns]

# %% [markdown]
# visualization

# %%
def turkish_lower(text):
    turkish_map = {
        'İ': 'i', 'I': 'ı',
        'Ğ': 'ğ', 'Ç': 'ç',
        'Ş': 'ş', 'Ö': 'ö',
        'Ü': 'ü'
    }
    return ''.join(turkish_map.get(c, c.lower()) for c in text)

def normalize_city_name(name):
    name = turkish_lower(name)
    return name.strip()

df_population = pd.read_csv('population.csv', encoding='utf-8')
df_location = pd.read_csv('corrected_location.csv', encoding='utf-8')

df_population.columns = df_population.columns.str.strip()
df_location.columns = df_location.columns.str.strip()

df_population['Şehir'] = df_population['Şehir'].apply(turkish_lower)
df_location['Şehir'] = df_location['Şehir'].apply(normalize_city_name)


df_cities = pd.merge(df_population, df_location, left_on='Şehir', right_on='Şehir')



m = folium.Map(location=[39.9334, 32.8597], zoom_start=6)

for idx, row in df_cities.iterrows():
    folium.Marker(
        location=[row['lat'], row['lon']],
        popup=f"{row['Şehir']}: {row['Nüfus']:,} people",
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(m)


transfer_dataset = pd.read_csv('transfer_results.csv', encoding='utf-8')
transfer_dataset['Source City'] = transfer_dataset['Source City'].apply(turkish_lower)
transfer_dataset['Destination City'] = transfer_dataset['Destination City'].apply(turkish_lower)


for idx, row in transfer_dataset.iterrows():
    src_city = row['Source City']
    dest_city = row['Destination City']
    amount = row['Amount']
  
    if src_city in df_cities['Şehir'].values and dest_city in df_cities['Şehir'].values:
        src_coords = df_cities[df_cities['Şehir'] == src_city][['lat', 'lon']].values[0]
        dest_coords = df_cities[df_cities['Şehir'] == dest_city][['lat', 'lon']].values[0]

        folium.PolyLine(
            locations=[src_coords, dest_coords],
            popup=f"{src_city} to {dest_city}: {amount:,} people",
            color='red',
            weight=2,
            opacity=0.6
        ).add_to(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_57bc6f0f195d37dc5eca6734e3db97c0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_57bc6f0f195d37dc5eca6734e3db97c0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_57bc6f0f195d37dc5eca6734e3db97c0 = L.map(
#                 &quot;map_57bc6f0f195d37dc5eca6734e3db97c0&quot;,
#                 {
#                     center: [39.9334, 32.8597],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_510277b611c220b4d169a21fec2ea63b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_57bc6f0f195d37dc5eca6734e3db97c0);
#
#
#             var marker_ba9b70d5aa7b5abc5c6d8f50dab104da = L.marker(
#                 [37.0, 35.3213333],
#                 {}
#             ).addTo(map_57bc6f0f195d37dc5eca6734e3db97c0);
#
#
#             var icon_52288d70576a4a0bddd2498432aea965 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ba9b70d5aa7b5abc5c6d8f50dab104da.setIcon(icon_52288d70576a4a0bddd2498432aea965);
#
#
#         var popup_c543287e1308843724dc46bff10acab8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_589cf8565dd29176fc6a19068acad2e7 = $(`&lt;div id=&quot;html_589cf8565dd29176fc6a19068acad2e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;adana: 2,270,298 people&lt;/div&gt;`)[0];
#                 popup_c543287e1308843724dc46bff10acab8.setContent(html_589cf8565dd29176fc6a19068acad2e7);
#
#
#
#         marker_ba9b70d5aa7b5abc5c6d8f50dab104da.bindPopup(popup_c543287e1308843724dc46bff10acab8)
#         ;
#
#
#
#
#             var marker_5df9dc2e75b75e22cdba470692fa12b8 = L.marker(
#                 [37.7641667, 38.2761667],
#                 {}
#             ).addTo(map_57bc6f0f195d37dc5eca6734e3db97c0);
#
#
#             var icon_db41c3e42cd7eb36629bedf53d3985a0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5df9dc2e75b75e22cdba470692fa12b8.setIcon(icon_db41c3e42cd7eb36629bedf53d3985a0);
#
#
#         var popup_5401408214d4cf4a6b3050f33eac4cd2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ca02b8452f2ea467a2a0dd8282a6c48a = $(`&lt;div id=&quot;html_ca02b8452f2ea467a2a0dd8282a6c48a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;adıyaman: 415,273 people&lt;/div&gt;`)[0];
#                 popup_5401408214d4cf4a6b3050f33eac4cd2.setContent(html_ca02b8452f2ea467a2a0dd8282a6c48a);
#
#
#
#         marker_5df9dc2e75b75e22cdba470692fa12b8.bindPopup(popup_5401408214d4cf4a6b3050f33eac4cd2)
#         ;
#
#
#
#
#             var marker_0e020f0cc2daa736e26b1ad164a99f80 = L.marker(
#                 [38.76376, 30.54034],
#                 {}
#             ).addTo(map_57bc6f0f195d37dc5eca6734e3db97c0);
#
#
#             var icon_874048d5741a395c530c1b0e9a9c1844 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0e020f0cc2daa736e26b1ad164a99f80.setIcon(icon_874048d5741a395c530c1b0e9a9c1844);
#
#
#         var popup_bc4e48bf8d3d619d2f4cafa23935bbd6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c573dacb5a56783cec19c18012967549 = $(`&lt;div id=&quot;html_c573dacb5a56783cec19c18012967549&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;afyonkarahisar: 458,364 people&lt;/div&gt;`)[0];
#                 popup_bc4e48bf8d3d619d2f4cafa23935bbd6.setContent(html_c573dacb5a56783cec19c18012967549);
#
#
#
#         marker_0e020f0cc2daa736e26b1ad164a99f80.bindPopup(popup_bc4e48bf8d3d619d2f4cafa23935bbd6)
#         ;
#
#
#
#
#             var marker_a327a78f215177b59d05f65723703239 = L.marker(
#                 [38.36869, 34.03698],
#                 {}
#             ).addTo(map_57bc6f0f195d37dc5eca6734e3db97c0);
#
#
#             var icon_d4f0a18d862050946f43f812b8a68112 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
